# %%
from langgraph.checkpoint.postgres.aio import AsyncPostgresSaver
from langgraph.checkpoint.redis.aio import AsyncRedisSaver
import os
from dotenv import load_dotenv

load_dotenv()
collection_name = "847f5e78-25b0-46b0-8188-1ebefd9c2772"
config = {"configurable": {"thread_id": collection_name}}

async with AsyncRedisSaver.from_conn_string(
        os.getenv("REDIS_URI"), 
        ttl={"default_ttl": 3600, "refresh_on_read": True}
    ) as redis_cp:
    
    await redis_cp.adelete_thread(collection_name)
    redis_state = await redis_cp.aget_tuple(config)
    pass

async with AsyncPostgresSaver.from_conn_string(
        os.getenv("DB_URI"), 
    ) as pg_cp:

    await pg_cp.adelete_thread(collection_name)
    pg_state = await pg_cp.aget_tuple(config)
    # await pg_cp.
    pass

# %%
pg_state.checkpoint
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 pg_state.checkpoint
#
# AttributeError: 'NoneType' object has no attribute 'checkpoint'

# %%
res = await pg_cp.aput()

# %%
from langchain_core.messages import HumanMessage, AIMessage
res = {'messages': [HumanMessage(content='سلام، وقتتون بخیر. من سه روزه درد شدید دندان دارم و صورت\u200cم متورم شده. هر دکتری که زنگ می\u200cزنم می\u200cگه تعطیله. لطفاً یه دکتر دندانپزشک اورژانسی پیدا کنید هرچه سریعتر.', additional_kwargs={}, response_metadata={}, id='8b8b510e-d90d-434e-b76e-96aecce38b93'), AIMessage(content='سلام. برای اینکه بتوانیم بهترین دندانپزشک اورژانسی را در شهر شما پیدا کنیم، لطفاً نام کامل بیمار (شما یا بیمار دیگر)، شماره تماس و شهر محل اقامت ایشان را بفرمایید.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 51, 'prompt_tokens': 181, 'total_tokens': 232, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'Qwen3.5-4B-Q8_0.gguf', 'system_fingerprint': 'b9159-5c0e94683', 'id': 'chatcmpl-ICZqZhgH1Y62CBJdNQxb3BWr58xIzXtf', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a061c8-6880-7b32-a4fd-cb5b32151085-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 181, 'output_tokens': 51, 'total_tokens': 232, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='اسم بیمار علی عباسی است.', additional_kwargs={}, response_metadata={}, id='2ae2104d-76de-4859-9ab3-d2b142002b76'), AIMessage(content='برای تکمیل اطلاعات، لطفاً شهر محل اقامت ایشان و شماره تماس برای ارتباط با ما را نیز بفرمایید.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 251, 'total_tokens': 282, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'Qwen3.5-4B-Q8_0.gguf', 'system_fingerprint': 'b9159-5c0e94683', 'id': 'chatcmpl-oOzrkB3sq3mWccHzUhjhD9CyzKkixeL0', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a061c8-6d5b-73d3-a11e-adbca66d5d28-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 251, 'output_tokens': 31, 'total_tokens': 282, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='بله. شماره من ۰۳۱-۳۳۵۵-۴۴۸۸ و در نزدیکی تهران سکونت دارم.', additional_kwargs={}, response_metadata={}, id='0691f77d-6642-4a7f-9b0f-cb893f6ce532')], 'resource_collection_name': '847f5e78-25b0-46b0-8188-1ebefd9c2772', 'enhanced_queries': {'dense': 'پزشک دندانپزشک اورژانسی در تهران برای درد شدید دندان و تورم صورت', 'sparse': 'دندانپزشک اورژانسی تهران درد شدید دندان تورم صورت'}, 'resource_points': [{'lc': 2, 'type': 'constructor', 'id': ['qdrant_client', 'http', 'models', 'models', 'ScoredPoint'], 'kwargs': {'id': 'd70ae4c7-a69c-4086-9fca-d269cdb7f78f', 'version': 3, 'score': 1.0, 'payload': {'id': 47, 'name': 'دکتر سارا رحیمی', 'profession': 'متخصص دندانپزشکی ترمیمی و زیبایی', 'title': 'رییس بخش دندانپزشکی ترمیمی', 'description': 'متخصص برجسته دندانپزشکی ترمیمی و زیبایی با تمرکز بر درمان\u200cهای بدون درد، لمینت سرامیکی، ایمپلنت\u200cهای دیجیتال و ارتودنسی نامرئی. همکار رسمی کلینیک\u200cهای بین\u200cالمللی و عضو انجمن دندانپزشکی زیبایی اروپا.', 'specialties': ['ایمپلنت دیجیتال', 'لمینت سرامیکی', 'ارتودنسی نامرئی (اینویزیلاین)', 'درمان ریشه (اندو)', 'جراحی لثه', 'بلیچینگ پیشرفته'], 'experience_years': 14, 'education': 'فلوشیپ ایمپلنتولوژی - دانشگاه برن سوئیس', 'hospital': 'کلینیک تخصصی دندانپزشکی مدرن', 'location': 'تهران، خیابان ولیعصر، بالاتر از میدان ونک، پلاک ۱۲۳', 'rating': 489, 'reviews_count': 234, 'availability': ['شنبه', 'یکشنبه', 'سه\u200cشنبه', 'پنجشنبه'], 'consultation_fee': 280, 'phone': '۰۲۱-۸۸۷۷-۱۲۳۴', 'email': 'dr.sara.rahimi@moderndental.com', 'is_accepting_patients': True, 'languages': ['فارسی', 'انگلیسی', 'آلمانی (مقدماتی)'], 'profile_image': 'sara_rahimi.jpg', 'page_content': 'دکتر سارا رحیمی متخصص دندانپزشکی ترمیمی و زیبایی رییس بخش دندانپزشکی ترمیمی متخصص برجسته دندانپزشکی ترمیمی و زیبایی با تمرکز بر درمان\u200cهای بدون درد، لمینت سرامیکی، ایمپلنت\u200cهای دیجیتال و ارتودنسی نامرئی. همکار رسمی کلینیک\u200cهای بین\u200cالمللی و عضو انجمن دندانپزشکی زیبایی اروپا. ایمپلنت دیجیتال, لمینت سرامیکی, ارتودنسی نامرئی (اینویزیلاین), درمان ریشه (اندو), جراحی لثه, بلیچینگ پیشرفته 14', 'reranker_score': 0.0019455725559964776}, 'vector': None, 'shard_key': None, 'order_value': None}}, {'lc': 2, 'type': 'constructor', 'id': ['qdrant_client', 'http', 'models', 'models', 'ScoredPoint'], 'kwargs': {'id': 'a7d3db15-1715-4a4c-8f46-90b34a495568', 'version': 2, 'score': 0.33333334, 'payload': {'id': 9, 'name': 'دکتر ندا مرادی', 'profession': 'متخصص روانپزشکی', 'title': 'فلوشیپ روانپزشکی کودک و نوجوان', 'description': 'ارائه خدمات تشخیصی و درمانی در حوزه افسردگی، اختلالات اضطرابی، اختلال نقص توجه/بیش\u200cفعالی (ADHD) و اختلالات طیف اوتیسم در کودکان و بزرگسالان.', 'specialties': ['روانپزشکی کودک', 'اختلالات اضطرابی', 'افسردگی', 'ADHD و اوتیسم'], 'experience_years': 13, 'education': 'فلوشیپ روانپزشکی کودک - دانشگاه علوم پزشکی تهران، روانپزشکی عمومی - ایران', 'hospital': 'مرکز تخصصی سلامت روان مهر', 'location': 'کرج، بلوار مطهری، خیابان هفتم', 'rating': 4.7, 'reviews_count': 189, 'availability': ['شنبه', 'دوشنبه', 'چهارشنبه'], 'schedule': {'شنبه': {'start': '10:00', 'end': '18:00', 'slots': 20}, 'دوشنبه': {'start': '10:00', 'end': '20:00', 'slots': 25}, 'چهارشنبه': {'start': '09:00', 'end': '17:00', 'slots': 22}}, 'consultation_fee': 270, 'phone': '۰۲۶-۳۲۲۵-۶۶۷۷', 'email': 'dr.neda.moradi@mehrmind.com', 'is_accepting_patients': 'true', 'languages': ['فارسی', 'انگلیسی'], 'profile_image': 'neda_moradi.jpg', 'page_content': 'دکتر ندا مرادی متخصص روانپزشکی فلوشیپ روانپزشکی کودک و نوجوان ارائه خدمات تشخیصی و درمانی در حوزه افسردگی، اختلالات اضطرابی، اختلال نقص توجه/بیش\u200cفعالی (ADHD) و اختلالات طیف اوتیسم در کودکان و بزرگسالان. روانپزشکی کودک, اختلالات اضطرابی, افسردگی, ADHD و اوتیسم 13', 'reranker_score': 8.857136708684266e-05}, 'vector': None, 'shard_key': None, 'order_value': None}}, {'lc': 2, 'type': 'constructor', 'id': ['qdrant_client', 'http', 'models', 'models', 'ScoredPoint'], 'kwargs': {'id': '2e809d17-3fe6-4139-9ff0-96ce3640f495', 'version': 1, 'score': 0.25, 'payload': {'id': 5, 'name': 'دکتر پریا شارما', 'profession': 'متخصص پوست', 'title': 'متخصص بالینی پوست', 'description': 'متخصص در پوست\u200cشناسی پزشکی، جراحی و زیبایی. تخصص در تشخیص سرطان پوست، درمان اگزما و درمان\u200cهای پیشرفته لیزر برای بیماری\u200cهای مختلف پوستی.', 'specialties': ['تشخیص سرطان پوست', 'درمان اگزما', 'درمان با لیزر', 'پوست\u200cشناسی زیبایی'], 'experience_years': 10, 'education': 'دکترای تخصصی پوست - دانشگاه پنسیلوانیا', 'hospital': 'مرکز پوست و مراقبت\u200cهای زیبایی', 'location': 'تبریز، خیابان امام خمینی', 'rating': 4.8, 'reviews_count': 256, 'availability': ['یکشنبه', 'سه\u200cشنبه', 'پنجشنبه'], 'schedule': {'یکشنبه': {'start': '10:00', 'end': '20:00', 'slots': 40}, 'سه\u200cشنبه': {'start': '10:00', 'end': '20:00', 'slots': 40}, 'پنجشنبه': {'start': '09:00', 'end': '15:00', 'slots': 24}}, 'consultation_fee': 220, 'phone': '۰۴۱-۵۵۵۵-۰۸۹۹', 'email': 'dr.priya.sharma@dermskincare.com', 'is_accepting_patients': True, 'languages': ['فارسی', 'انگلیسی', 'هندی'], 'profile_image': 'priya_sharma.jpg', 'page_content': 'دکتر پریا شارما متخصص پوست متخصص بالینی پوست متخصص در پوست\u200cشناسی پزشکی، جراحی و زیبایی. تخصص در تشخیص سرطان پوست، درمان اگزما و درمان\u200cهای پیشرفته لیزر برای بیماری\u200cهای مختلف پوستی. تشخیص سرطان پوست, درمان اگزما, درمان با لیزر, پوست\u200cشناسی زیبایی 10', 'reranker_score': 3.1140421924646944e-05}, 'vector': None, 'shard_key': None, 'order_value': None}}, {'lc': 2, 'type': 'constructor', 'id': ['qdrant_client', 'http', 'models', 'models', 'ScoredPoint'], 'kwargs': {'id': 'd6346447-1246-4729-ad2a-fbda05c4ec57', 'version': 2, 'score': 0.2, 'payload': {'id': 7, 'name': 'دکتر سیمین سعیدی', 'profession': 'متخصص کودکان', 'title': 'فوق تخصص بیماری\u200cهای غدد و متابولیک کودکان', 'description': 'پزشک اطفال با تمرکز بر اختلالات رشد، دیابت کودکان، بیماری\u200cهای تیروئید و اختلالات متابولیک مادرزادی با رویکردی خانواده\u200cمحور.', 'specialties': ['دیابت کودکان', 'اختلالات رشد', 'بیماری\u200cهای تیروئید', 'متابولیک مادرزادی'], 'experience_years': 16, 'education': 'فوق تخصص غدد کودکان - دانشگاه علوم پزشکی اصفهان، دکترای کودکان - شیراز', 'hospital': 'بیمارستان تخصصی کودکان امیرکبیر', 'location': 'تبریز، بلوار استاد شهریار، بیمارستان امیرکبیر', 'rating': 4.8, 'reviews_count': 375, 'availability': ['شنبه', 'سه\u200cشنبه', 'پنجشنبه'], 'schedule': {'شنبه': {'start': '08:00', 'end': '14:00', 'slots': 22}, 'سه\u200cشنبه': {'start': '09:00', 'end': '17:00', 'slots': 32}, 'پنجشنبه': {'start': '08:00', 'end': '12:00', 'slots': 16}}, 'consultation_fee': 200, 'phone': '۰۴۱-۳۲۲۴-۵۸۷۶', 'email': 'dr.simin.saeedi@amirkabirkids.com', 'is_accepting_patients': 'true', 'languages': ['فارسی', 'انگلیسی', 'ترکی'], 'profile_image': 'simin_saeedi.jpg', 'page_content': 'دکتر سیمین سعیدی متخصص کودکان فوق تخصص بیماری\u200cهای غدد و متابولیک کودکان پزشک اطفال با تمرکز بر اختلالات رشد، دیابت کودکان، بیماری\u200cهای تیروئید و اختلالات متابولیک مادرزادی با رویکردی خانواده\u200cمحور. دیابت کودکان, اختلالات رشد, بیماری\u200cهای تیروئید, متابولیک مادرزادی 16', 'reranker_score': 4.428559259395115e-05}, 'vector': None, 'shard_key': None, 'order_value': None}}, {'lc': 2, 'type': 'constructor', 'id': ['qdrant_client', 'http', 'models', 'models', 'ScoredPoint'], 'kwargs': {'id': '45a5b33e-2db7-492c-bc4e-266582e4cc8b', 'version': 2, 'score': 0.16666667, 'payload': {'id': 5, 'name': 'دکتر الناز شریفی', 'profession': 'متخصص پوست و مو', 'title': 'فلوشیپ زیبایی و لیزر درمانی', 'description': 'پزشک پوست با تمرکز بر درمان ضایعات پوستی، بیماری\u200cهای خودایمنی پوست، و روش\u200cهای پیشرفته جوانسازی و لیزر درمانی.', 'specialties': ['درماتولوژی بالینی', 'لیزر درمانی', 'پوست و مو', 'زیبایی پزشکی'], 'experience_years': 10, 'education': 'فلوشیپ لیزر درمانی - دانشگاه علوم پزشکی تهران، دکترای تخصصی پوست - شهید بهشتی', 'hospital': 'کلینیک تخصصی پوست و موی سپید', 'location': 'اصفهان، خیابان چهارباغ بالا، کوچه ۲۴', 'rating': 4.9, 'reviews_count': 521, 'availability': ['شنبه', 'دوشنبه', 'پنجشنبه'], 'schedule': {'شنبه': {'start': '10:00', 'end': '18:00', 'slots': 30}, 'دوشنبه': {'start': '10:00', 'end': '20:00', 'slots': 42}, 'پنجشنبه': {'start': '09:00', 'end': '14:00', 'slots': 20}}, 'consultation_fee': 220, 'phone': '۰۳۱-۳۳۵۵-۴۴۸۸', 'email': 'dr.elnaz.sharifi@sepidehclinic.com', 'is_accepting_patients': 'true', 'languages': ['فارسی', 'انگلیسی', 'فرانسوی'], 'profile_image': 'elnaz_sharifi.jpg', 'page_content': 'دکتر الناز شریفی متخصص پوست و مو فلوشیپ زیبایی و لیزر درمانی پزشک پوست با تمرکز بر درمان ضایعات پوستی، بیماری\u200cهای خودایمنی پوست، و روش\u200cهای پیشرفته جوانسازی و لیزر درمانی. درماتولوژی بالینی, لیزر درمانی, پوست و مو, زیبایی پزشکی 10', 'reranker_score': 0.0001490290742367506}, 'vector': None, 'shard_key': None, 'order_value': None}}], 'route_decision': 'looking_for_doctor', 'patient_info': {'city': 'تهران', 'province': 'تهران', 'name': 'علی عباسی', 'phone_number': '031-3355-4488'}, 'confirmation': '\n✅ نوبت شما با موفقیت ثبت شد\n\n👨\u200d⚕️ پزشک: دکتر سارا رحیمی\n🧠 تخصص: متخصص دندانپزشکی ترمیمی و زیبایی\n\n📅 تاریخ: پنجشنبه 12 Shahrivar 1405\n🕐 ساعت: 10:00\n\n📍 محل:\nکلینیک تخصصی دندانپزشکی مدرن\nتهران، خیابان ولیعصر، بالاتر از میدان ونک، پلاک ۱۲۳\n\n👤 بیمار: علی عباسی\n\n💳 هزینه ویزیت: 280 تومان\n\n📞 تلفن مرکز: ۰۲۱-۸۸۷۷-۱۲۳۴\n\n🔖 کد پیگیری: AP-47-0506121000\n\nوضعیت نوبت: تأیید شده ✅\n\nلطفاً ۱۰ تا ۱۵ دقیقه پیش از زمان نوبت در مرکز حضور داشته باشید.\n', 'before_interrupt': {'message': 'Please review the candidate doctors before booking', 'candidate_doctors': [{'id': 47, 'name': 'دکتر سارا رحیمی', 'profession': 'متخصص دندانپزشکی ترمیمی و زیبایی', 'title': 'رییس بخش دندانپزشکی ترمیمی', 'description': 'متخصص برجسته دندانپزشکی ترمیمی و زیبایی با تمرکز بر درمان\u200cهای بدون درد، لمینت سرامیکی، ایمپلنت\u200cهای دیجیتال و ارتودنسی نامرئی. همکار رسمی کلینیک\u200cهای بین\u200cالمللی و عضو انجمن دندانپزشکی زیبایی اروپا.', 'specialties': ['ایمپلنت دیجیتال', 'لمینت سرامیکی', 'ارتودنسی نامرئی (اینویزیلاین)', 'درمان ریشه (اندو)', 'جراحی لثه', 'بلیچینگ پیشرفته'], 'experience_years': 14, 'education': 'فلوشیپ ایمپلنتولوژی - دانشگاه برن سوئیس', 'hospital': 'کلینیک تخصصی دندانپزشکی مدرن', 'location': 'تهران، خیابان ولیعصر، بالاتر از میدان ونک، پلاک ۱۲۳', 'rating': 489, 'reviews_count': 234, 'availability': ['شنبه', 'یکشنبه', 'سه\u200cشنبه', 'پنجشنبه'], 'consultation_fee': 280, 'phone': '۰۲۱-۸۸۷۷-۱۲۳۴', 'email': 'dr.sara.rahimi@moderndental.com', 'is_accepting_patients': True, 'languages': ['فارسی', 'انگلیسی', 'آلمانی (مقدماتی)'], 'profile_image': 'sara_rahimi.jpg', 'page_content': 'دکتر سارا رحیمی متخصص دندانپزشکی ترمیمی و زیبایی رییس بخش دندانپزشکی ترمیمی متخصص برجسته دندانپزشکی ترمیمی و زیبایی با تمرکز بر درمان\u200cهای بدون درد، لمینت سرامیکی، ایمپلنت\u200cهای دیجیتال و ارتودنسی نامرئی. همکار رسمی کلینیک\u200cهای بین\u200cالمللی و عضو انجمن دندانپزشکی زیبایی اروپا. ایمپلنت دیجیتال, لمینت سرامیکی, ارتودنسی نامرئی (اینویزیلاین), درمان ریشه (اندو), جراحی لثه, بلیچینگ پیشرفته 14', 'reranker_score': 0.0019455725559964776}], 'total_candidates': 1, 'options': ['select_doctor', 'modify_criteria', 'cancel_booking']}}

# %%
res['confirmation']
# Out:
# '\n✅ نوبت شما با موفقیت ثبت شد\n\n👨\u200d⚕️ پزشک: دکتر سارا رحیمی\n🧠 تخصص: متخصص دندانپزشکی ترمیمی و زیبایی\n\n📅 تاریخ: پنجشنبه 12 Shahrivar 1405\n🕐 ساعت: 10:00\n\n📍 محل:\nکلینیک تخصصی دندانپزشکی مدرن\nتهران، خیابان ولیعصر، بالاتر از میدان ونک، پلاک ۱۲۳\n\n👤 بیمار: علی عباسی\n\n💳 هزینه ویزیت: 280 تومان\n\n📞 تلفن مرکز: ۰۲۱-۸۸۷۷-۱۲۳۴\n\n🔖 کد پیگیری: AP-47-0506121000\n\nوضعیت نوبت: تأیید شده ✅\n\nلطفاً ۱۰ تا ۱۵ دقیقه پیش از زمان نوبت در مرکز حضور داشته باشید.\n'

# %%
state.checkpoint['channel_values']["confirmation"]
# Out:
# '\n✅ نوبت شما با موفقیت ثبت شد\n\n👨\u200d⚕️ پزشک: دکتر مایکل چن\n🧠 تخصص: متخصص مغز و اعصاب\n\n📅 تاریخ: پنجشنبه 12 Shahrivar 1405\n🕐 ساعت: 10:00\n\n📍 محل:\nمرکز علوم اعصاب پاسیفیک\nمشهد، بلوار وکیل\u200cآباد\n\n👤 بیمار: محمد علی ایران دوست\n\n💳 هزینه ویزیت: 300 تومان\n\n📞 تلفن مرکز: ۰۵۱-۵۵۵۵-۰۴۵۶\n\n🔖 کد پیگیری: AP-2-0506121000\n\nوضعیت نوبت: تأیید شده ✅\n\nلطفاً ۱۰ تا ۱۵ دقیقه پیش از زمان نوبت در مرکز حضور داشته باشید.\n'

# %%
print(f"""
Extract patient information from the conversation.

Extract the following fields independently:

- patient_name: The patient's full name, only if explicitly provided.
- city: The patient's city of residence, only if explicitly provided.

Rules:
- Either field may be present without the other.
- Both fields may be present.
- Neither field may be present.
- Only extract information explicitly stated in the conversation.
- Never guess, infer, or fabricate information.
- If a field is not explicitly provided, return None for that field.
- Only ask the missing information.

current information about user that we have:
name: {None}
city: {None}
""")
# Out:
# Extract patient information from the conversation.
#
# Extract the following fields independently:
#
# - patient_name: The patient's full name, only if explicitly provided.
# - city: The patient's city of residence, only if explicitly provided.
#
# Rules:
# - Either field may be present without the other.
# - Both fields may be present.
# - Neither field may be present.
# - Only extract information explicitly stated in the conversation.
# - Never guess, infer, or fabricate information.
# - If a field is not explicitly provided, return None for that field.
#
# current information about user that we have:
# name: None
# city: None

# %%
state.checkpoint['channel_values']['messages']
# Out:
# [HumanMessage(content='سلام، وقتتون بخیر', additional_kwargs={}, response_metadata={}, id='732df879-b2af-410b-b5c0-76ba2913f24b'),
#  AIMessage(content='در کدام شهر سکونت دارید؟', additional_kwargs={}, response_metadata={}, id='8483a8fd-147c-49f8-9202-ed2a80127407', tool_calls=[], invalid_tool_calls=[])]

# %%
from qdrant_client import AsyncQdrantClient, models

client = AsyncQdrantClient(
    host="localhost",
    port=6333,
    https=False,
    api_key="123456789",
)


# OLD_COLLECTION = "847f5e78-25b0-46b0-8188-1ebefd9c2772"
COLLECTION = "doctors"

# 1. Create the new hybrid collection
if not await client.collection_exists(COLLECTION):
    await client.create_collection(
        collection_name=COLLECTION,
        vectors_config={
            "dense": models.VectorParams(
                size=1024,  # <-- your embedding dimension
                distance=models.Distance.COSINE,
            )
        },
        sparse_vectors_config={
            "bm25": models.SparseVectorParams(
                modifier=models.Modifier.IDF,
            )
        },
    )
# Out:
# /tmp/ipykernel_133925/683747123.py:3: UserWarning: Api key is used with an insecure connection.
#   client = AsyncQdrantClient(

# %%
from langchain.embeddings import init_embeddings
from app.receptionist.dummy_docs import doctors_plus_10

tempo_add = [{
        "id": 47,
        "name": "دکتر سارا رحیمی",
        "profession": "متخصص دندانپزشکی ترمیمی و زیبایی",
        "title": "رییس بخش دندانپزشکی ترمیمی",
        "description": "متخصص برجسته دندانپزشکی ترمیمی و زیبایی با تمرکز بر درمان‌های بدون درد، لمینت سرامیکی، ایمپلنت‌های دیجیتال و ارتودنسی نامرئی. همکار رسمی کلینیک‌های بین‌المللی و عضو انجمن دندانپزشکی زیبایی اروپا.",
        "specialties": ["ایمپلنت دیجیتال", "لمینت سرامیکی", "ارتودنسی نامرئی (اینویزیلاین)", "درمان ریشه (اندو)", "جراحی لثه", "بلیچینگ پیشرفته"],
        "experience_years": 14,
        "education": "فلوشیپ ایمپلنتولوژی - دانشگاه برن سوئیس",
        "hospital": "کلینیک تخصصی دندانپزشکی مدرن",
        "location": "تهران، خیابان ولیعصر، بالاتر از میدان ونک، پلاک ۱۲۳",
        "rating": 489,
        "reviews_count": 234,
        "availability": ["شنبه", "یکشنبه", "سه‌شنبه", "پنجشنبه"],
        "consultation_fee": 280,
        "phone": "۰۲۱-۸۸۷۷-۱۲۳۴",
        "email": "dr.sara.rahimi@moderndental.com",
        "is_accepting_patients": True,
        "languages": ["فارسی", "انگلیسی", "آلمانی (مقدماتی)"],
        "profile_image": "sara_rahimi.jpg"
    }]


embedding_model = init_embeddings(
    model="openai:qwen3_0.6B_gguf",
    # model_provider="openai",
    api_key="not-needed",
    base_url="http://0.0.0.0:8080/v1",
    check_embedding_ctx_length=False,
)
to_embed_s = []
for d in tempo_add:
    # print(d['name'])
    to_embed = d['name'] + " " + d['profession'] + " " + d['title'] + " " + d['description'] + " " + ", ".join(d['specialties']) + ' ' + str(d['experience_years'])
    to_embed_s.append(to_embed)


embeddings = await embedding_model.aembed_documents(to_embed_s)

# %%
from app.container import container

embedding_model = container.embedding_model()

res = await embedding_model.aembed_query("hello there!")

# %%
# "name": "دکتر پریا شارما",
# "profession": "متخصص پوست",
# "title": "متخصص بالینی پوست",
# "description": "متخصص در پوست‌شناسی پزشکی، جراحی و زیبایی. تخصص در تشخیص سرطان پوست، درمان اگزما و درمان‌های پیشرفته لیزر برای بیماری‌های مختلف پوستی.",
# "specialties": ["تشخیص سرطان پوست", "درمان اگزما", "درمان با لیزر", "پوست‌شناسی زیبایی"],
# "experience_years": 10,
# Out:
# دکتر سارا جانسون متخصص قلب و عروق متخصص ارشد قلب و عروق متخصص در قلب‌شناسی مداخله‌ای و مدیریت نارسایی قلبی با بیش از ۱۵ سال تجربه در درمان بیماری‌های پیچیده قلبی. قلب‌شناسی مداخله‌ای, نارسایی قلبی, اکوکاردیوگرافی 15

# %%
from uuid import uuid4
points = []
for i, doctor in enumerate(tempo_add):
    tempo_add[i]['page_content'] = to_embed_s[i]
    points.append(models.PointStruct(
        id=str(uuid4()),
        vector={
            "dense": embeddings[i],
            "bm25": models.Document(
                text=to_embed_s[i],
                model="qdrant/bm25",
            ),
        },
        payload=tempo_add[i],
    ))

# %%
await client.upsert(
    collection_name="doctors",
    points=points,
)
# Out:
# UpdateResult(operation_id=3, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
appointment_requirements = {
    "doctor": None, # the user will choose among the options we present him after fetching from available doctors.
    "date": None,
    "time": None,
    "address": None,
    "patient": None,
    "phone_number": None,
}

# doctor_selection_requirements = {
#     "specialty": None,
#     "location": None,
#     "date": None,
#     "time": None,
# }

# %%
import hashlib

def content_id(content: str) -> str:
    return hashlib.sha256(content.encode("utf-8")).hexdigest()

# %%
from qdrant_client import AsyncQdrantClient, models

client = AsyncQdrantClient(
    host="localhost",
    port=6333,
    https=False,
    api_key="123456789",
)


# OLD_COLLECTION = "847f5e78-25b0-46b0-8188-1ebefd9c2772"
COLLECTION = "847f5e78-25b0-46b0-8188-1ebefd9c2772_test_hybrid"

# 1. Create the new hybrid collection
await client.create_collection(
    collection_name=COLLECTION,
    vectors_config={
        "dense": models.VectorParams(
            size=1024,  # <-- your embedding dimension
            distance=models.Distance.COSINE,
        )
    },
    sparse_vectors_config={
        "bm25": models.SparseVectorParams(
            modifier=models.Modifier.IDF,
        )
    },
)
# Out:
# True

# %%
points, _ = await client.scroll(
    collection_name=COLLECTION,
    limit=1000,
    with_payload=True,
    with_vectors=True,
)
interaction_content = ""


page_content_hash = content_id(interaction_content)

page_content_hashes = [p.payload['page_content'] for p in points]
for hash in page_content_hashes:
    if hash == page_content_hash:
        print("duplicate exists")
        print(hash)

# %%
from qdrant_client import models

points, _ = await client.scroll(
    collection_name=COLLECTION,
    limit=1000,
    with_payload=True,
    with_vectors=True,
)

updated_points = []

for point in points:
    page_content = point.payload["page_content"]

    updated_points.append(
        models.PointStruct(
            id=point.id,
            vector={
                "dense": point.vector["dense"],
                "bm25": models.Document(
                    text=page_content,
                    model="qdrant/bm25",
                ),
            },
            payload=point.payload,
        )
    )

await client.upsert(
    collection_name=COLLECTION,
    points=updated_points,
)

print(f"Updated {len(updated_points)} points")
# Out:
# Updated 196 points

# %%
from qdrant_client import  models

COLLECTION = "847f5e78-25b0-46b0-8188-1ebefd9c2772_test_hybrid"



res = await client.query_points(
    collection_name=COLLECTION,
    query=models.Document(
        text="How to bake cookies?", 
        model="Qdrant/bm25",
    ),
    using="bm25",
)



res
# Out:
# QueryResponse(points=[])

# %%
dense_results = await client.query_points(
    collection_name=COLLECTION,
    query=[0.6] * 1024,
    using="dense",
    limit=20,
    with_payload=True,
)
for point in dense_results.points[:5]:
    print(f"ID: {point.id}, Score: {point.score}")
# Out:
# ID: ce519f25-a407-09cd-f1e0-2db1c27cf532, Score: 0.055745132
# ID: b76b0803-4c65-465f-99d7-5cb4e6403075, Score: 0.041850157
# ID: 586c81ca-1180-df7a-319e-da8e6756352f, Score: 0.03845218
# ID: 76f7955f-5004-a3e1-eb0a-09a39a034dad, Score: 0.036447246
# ID: 7ef85153-a19d-6983-219a-44962f96ef6f, Score: 0.032678902

# %%
client.vers

# %%
OLD_COLLECTION = "847f5e78-25b0-46b0-8188-1ebefd9c2772_test_hybrid"

client = AsyncQdrantClient(
    host="localhost",
    port=6333,
    https=False,
    api_key="123456789",
)

offset = None
BATCH_SIZE = 500

while True:
    points, next_offset = await client.scroll(
        collection_name=OLD_COLLECTION,
        limit=BATCH_SIZE,
        offset=offset,
        with_payload=True,
        with_vectors=True,
    )

    print(f"Retrieved {len(points)} points")
    print(f"Current offset: {offset}")
    print(f"Next offset: {next_offset}")

    # Process points here
    # print(points[:10])

    # No more pages
    if next_offset is None:
        break

    offset = next_offset
# Out:
# Retrieved 195 points
# Current offset: None
# Next offset: None
# /tmp/ipykernel_14672/914076297.py:5: UserWarning: Api key is used with an insecure connection.
#   client = AsyncQdrantClient(
